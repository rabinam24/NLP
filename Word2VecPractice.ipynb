# %% [markdown]
# <a href="https://colab.research.google.com/github/rabinam24/NLP/blob/main/Word2VecPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Word2Vec Practice on the friends dataset

# %%
import numpy as np
import pandas as pd
import gensim
import os
from gensim.models import Word2Vec,KeyedVectors
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import os
from nltk import sent_tokenize, word_tokenize
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords

# Download stopwords (if not already downloaded)
import nltk
nltk.download('stopwords')

# Load English stopwords from NLTK
stop_words = set(stopwords.words('english'))

story = []

# Specify the correct directory path
directory_path = '/content/drive/MyDrive/Friends'

for filename in os.listdir(directory_path):
    file_path = os.path.join(directory_path, filename)

    with open(file_path, 'r', encoding='latin-1') as file:
        corpus = file.read()
        raw_sentences = sent_tokenize(corpus)

        for sent in raw_sentences:
            # Tokenize the sentence into words
            words = simple_preprocess(sent)

            # Remove stopwords
            filtered_words = [word for word in words if word.lower() not in stop_words]

            story.append(filtered_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
len(story)
# Out:
# 113850

# %%
model = gensim.models.Word2Vec(
    window =7,
    min_count=2,
)

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count,epochs=5)
# Out:
# (2797671, 4512395)

# %%
model.wv.most_similar('ross')
# Out:
# [('joey', 0.9410381317138672),
#  ('phoebe', 0.9207533001899719),
#  ('monica', 0.9126443862915039),
#  ('rachel', 0.899196982383728),
#  ('chandler', 0.8813753724098206),
#  ('mnca', 0.8296723961830139),
#  ('phoe', 0.8217565417289734),
#  ('blind', 0.8109248876571655),
#  ('charlie', 0.8063424229621887),
#  ('scene', 0.8060881495475769)]

# %%
model.wv.similarity('rachel','ross')
# Out:
# 0.899197

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.10912096, -0.0353721 , -0.02762803, ..., -0.05898799,
#          0.03321494,  0.18191563],
#        [-0.07114551,  0.08510136, -0.0090605 , ..., -0.02166616,
#         -0.09764352,  0.06847776],
#        [-0.01674275, -0.07241878, -0.1119649 , ..., -0.0063976 ,
#          0.01229089, -0.0983199 ],
#        ...,
#        [ 0.04222773,  0.15138008,  0.05762667, ..., -0.00144544,
#         -0.00954801,  0.02037432],
#        [-0.0170773 ,  0.06496909, -0.02545955, ...,  0.01013739,
#         -0.07115835, -0.01868642],
#        [-0.01473845,  0.11354398,  0.01409972, ..., -0.00071621,
#          0.02682613,  0.03172125]], dtype=float32)

# %%
y= model.wv.index_to_key
y
# Out:
# ['one',
#  'friends',
#  'episode',
#  'season',
#  'ross',
#  'rachel',
#  'joey',
#  'chandler',
#  'monica',
#  'phoebe',
#  'oh',
#  'know',
#  'yeah',
#  'okay',
#  'iâ',
#  'well',
#  'hey',
#  'like',
#  'right',
#  'gonna',
#  'scene',
#  'get',
#  'go',
#  'wedding',
#  'rachelâ',
#  'really',
#  'uh',
#  'look',
#  'itâ',
#  'think',
#  'donâ',
#  'got',
#  'back',
#  'baby',
#  'joeyâ',
#  'see',
#  'new',
#  'mean',
#  'two',
#  'youâ',
#  'sister',
#  'gets',
#  'rossâ',
#  'want',
#  'come',
#  'good',
#  'could',
#  'dies',
#  'big',
#  'monicaâ',
#  'god',
#  'party',
#  'guy',
#  'would',
#  'guys',
#  'going',
#  'thatâ',
#  'sorry',
#  'canâ',
#  'ok',
#  'man',
#  'hi',
#  'time',
#  'kiss',
#  'little',
#  'great',
#  'thing',
#  'girl',
#  'take',
#  'away',
#  'say',
#  'tell',
#  'work',
#  'yes',
#  'dad',
#  'phone',
#  'yâ',
#  'door',
#  'something',
#  'break',
#  'night',
#  'parts',
#  'room',
#  'moves',
#  'wait',
#  'mr',
#  'goes',
# ...

# %%
len(y)
# Out:
# 10790

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
X= pca.fit_transform(model.wv.get_normed_vectors())

# %%
X
# Out:
# array([[ 1.0046641 ,  0.16848654,  0.29988497],
#        [ 0.8849745 ,  0.21310107,  0.3220773 ],
#        [ 1.0405506 ,  0.16544002,  0.30921704],
#        ...,
#        [ 0.22984679, -0.4088578 ,  0.11497814],
#        [ 0.06178151,  0.09663719, -0.22093304],
#        [ 0.33106437, -0.30698642, -0.12566549]], dtype=float32)

# %%
X.shape
# Out:
# (10790, 3)

# %%
import plotly.express as px
figure= px.scatter_3d(X[:100],x=0,y=1,z=2,color=y[:100])
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
